# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Python Coding Exercises
#
# _Authors: Joseph Nelson (DC) _
#
# ---

# %% [markdown]
# The following code challenges are drawn from common exercises used in technical interviews.
#
# Note that there may be several ways to approach each challenge!

# %% [markdown]
# ### Challenge 1.1: Largest Palindrome
# A palindromic number reads the same both ways. For example, 1234321 is a palindrome. The largest palindrome made from the product of two two-digit numbers is 9009 = 91 × 99. Find the largest palindrome made from the product of two three-digit numbers.

# %%
palindrome_outcome=0
largest_palindrome=0
for i in range(1,1000):
    for j in range(1,1000):
        result=i*j
        n=0
        same_so_far_bool=True
        for char in str(result):
            n+=1
            if same_so_far_bool==True and str(result)[n-1]==str(result)[-(n)]:
                same_so_far_bool=True
            else:
                same_so_far_bool=False
        if same_so_far_bool==True:
            palindrome_outcome=result
            if palindrome_outcome>largest_palindrome:
                largest_palindrome=palindrome_outcome
print(largest_palindrome)
# Out:
# 906609

# %% [markdown]
# ### Challenge 1.2: Summation of Primes
# The sum of the primes below 10 is 2 + 3 + 5 + 7 = 17. Find the sum of all the primes below 2,000.

# %%
prime_sum=0
for num in range (2,2000):
    prime_bool=True
    for i in range(2,num):
        if prime_bool==True:
            if num%i == 0:
                prime_bool=False
    if prime_bool==True:
        prime_sum=prime_sum + num
print(prime_sum)
# Out:
# 277050

# %% [markdown]
# ### Challenge 1.3: Multiples of 3 and 5
# If we list all of the natural numbers below 10 that are multiples of 3 or 5, we get 3, 5, 6, and 9. The sum of these multiples is 23. Find the sum of all the multiples of 3 and 5 below 1,000.

# %%
multiple_3n5_sum = 0
for i in range (3,1000):
        if i%3==0 or i%5==0:
            multiple_3n5_sum = multiple_3n5_sum + i
print (multiple_3n5_sum)
# Out:
# 233168

# %% [markdown]
# ### Challenge 2: FizzBuzz
# Write a program that prints all of the numbers from 1 to 100. For multiples of 3, instead of the number, print "Fizz;" for multiples of 5, print "Buzz." For numbers that are multiples of both 3 and 5, print "FizzBuzz." Bonus: If that's too easy, create three unique solutions. Sometimes you'll encounter unexpected constraints, so make sure you're able to think creatively!

# %%
for i in range (1,101):
    if i%3==0 and i%5==0:
        print ("FizzBuzz.")
    elif i%3==0:
        print ("Fizz;")
    elif i%5==0:
        print ("Buzz.")
    else:
        print (i)
# Out:
# 1
# 2
# Fizz;
# 4
# Buzz.
# Fizz;
# 7
# 8
# Fizz;
# Buzz.
# 11
# Fizz;
# 13
# 14
# FizzBuzz.
# 16
# 17
# Fizz;
# 19
# Buzz.
# Fizz;
# 22
# 23
# Fizz;
# Buzz.
# 26
# Fizz;
# 28
# 29
# FizzBuzz.
# 31
# 32
# Fizz;
# 34
# Buzz.
# Fizz;
# 37
# 38
# Fizz;
# Buzz.
# 41
# Fizz;
# 43
# 44
# FizzBuzz.
# 46
# 47
# Fizz;
# 49
# Buzz.
# Fizz;
# 52
# 53
# Fizz;
# Buzz.
# 56
# Fizz;
# 58
# 59
# FizzBuzz.
# 61
# 62
# Fizz;
# 64
# Buzz.
# Fizz;
# 67
# 68
# Fizz;
# Buzz.
# 71
# Fizz;
# 73
# 74
# FizzBuzz.
# 76
# 77
# Fizz;
# 79
# Buzz.
# Fizz;
# 82
# 83
# Fizz;
# Buzz.
# 86
# Fizz;
# 88
# 89
# FizzBuzz.
# 91
# 92
# Fizz;
# 94
# Buzz.
# Fizz;
# 97
# 98
# Fizz;
# Buzz.

# %%
for i in range (1,101):
    if i%3==0:
        if i%5==0:
            print ("FizzBuzz.")
        else:
            print ("Fizz;")
    elif i%5==0:
        print ("Buzz.")
    else:
        print (i)
# Out:
# 1
# 2
# Fizz;
# 4
# Buzz.
# Fizz;
# 7
# 8
# Fizz;
# Buzz.
# 11
# Fizz;
# 13
# 14
# FizzBuzz.
# 16
# 17
# Fizz;
# 19
# Buzz.
# Fizz;
# 22
# 23
# Fizz;
# Buzz.
# 26
# Fizz;
# 28
# 29
# FizzBuzz.
# 31
# 32
# Fizz;
# 34
# Buzz.
# Fizz;
# 37
# 38
# Fizz;
# Buzz.
# 41
# Fizz;
# 43
# 44
# FizzBuzz.
# 46
# 47
# Fizz;
# 49
# Buzz.
# Fizz;
# 52
# 53
# Fizz;
# Buzz.
# 56
# Fizz;
# 58
# 59
# FizzBuzz.
# 61
# 62
# Fizz;
# 64
# Buzz.
# Fizz;
# 67
# 68
# Fizz;
# Buzz.
# 71
# Fizz;
# 73
# 74
# FizzBuzz.
# 76
# 77
# Fizz;
# 79
# Buzz.
# Fizz;
# 82
# 83
# Fizz;
# Buzz.
# 86
# Fizz;
# 88
# 89
# FizzBuzz.
# 91
# 92
# Fizz;
# 94
# Buzz.
# Fizz;
# 97
# 98
# Fizz;
# Buzz.

# %%
for i in range(1,101):
    if i%3!=0 and i%5!=0:
        print (i)
    elif i%3==0 and i%5!=0:
        print ("Fizz;")
    elif i%3!=0 and i%5==0:
        print ("Buzz.")
    else:
        print ("FizzBuzz.")
# Out:
# 1
# 2
# Fizz;
# 4
# Buzz.
# Fizz;
# 7
# 8
# Fizz;
# Buzz.
# 11
# Fizz;
# 13
# 14
# FizzBuzz.
# 16
# 17
# Fizz;
# 19
# Buzz.
# Fizz;
# 22
# 23
# Fizz;
# Buzz.
# 26
# Fizz;
# 28
# 29
# FizzBuzz.
# 31
# 32
# Fizz;
# 34
# Buzz.
# Fizz;
# 37
# 38
# Fizz;
# Buzz.
# 41
# Fizz;
# 43
# 44
# FizzBuzz.
# 46
# 47
# Fizz;
# 49
# Buzz.
# Fizz;
# 52
# 53
# Fizz;
# Buzz.
# 56
# Fizz;
# 58
# 59
# FizzBuzz.
# 61
# 62
# Fizz;
# 64
# Buzz.
# Fizz;
# 67
# 68
# Fizz;
# Buzz.
# 71
# Fizz;
# 73
# 74
# FizzBuzz.
# 76
# 77
# Fizz;
# 79
# Buzz.
# Fizz;
# 82
# 83
# Fizz;
# Buzz.
# 86
# Fizz;
# 88
# 89
# FizzBuzz.
# 91
# 92
# Fizz;
# 94
# Buzz.
# Fizz;
# 97
# 98
# Fizz;
# Buzz.

# %% [markdown]
# ### Challenge 3: String Compressor
# Implement a method to perform basic string compression using the counts of repeated characters. (This is called run-length encoding.) For example, the string "aabcccccaaa" would become a2b1c5a3. If the “compressed” string would not become smaller than the original string, your method should return the original string. You can assume the string has only uppercase and lowercase letters (a–z). Specify whether your solution is case sensitive or case insensitive and what you would need to change to make it the other.

# %%
# my solution below is case sensitive
# to make it case insensitive, I can add one line "string_value=string_value.upper()" after the def line
def run_length_encoding (string_value):
    n=0
    count_repetition=0
    prev_value=' '
    run_length_compressed=''
    for char in string_value:
        n+=1
        if char == prev_value:
            count_repetition+=1
        else:
            if n!=1:
                run_length_compressed=run_length_compressed+prev_value
                run_length_compressed=run_length_compressed+str(count_repetition)
            count_repetition=1
            prev_value=char
    run_length_compressed=run_length_compressed+char
    run_length_compressed=run_length_compressed+str(count_repetition)
    if len(run_length_compressed)<len(string_value):
        print (run_length_compressed)
    else:
        print (string_value)

run_length_encoding ("abc")
run_length_encoding ("aabcccccaaa")
run_length_encoding ("aabcccccaaAAAAAAABcDgggbbe")
run_length_encoding ("aabcccccaaAAAerAvBcDgggbbe")
run_length_encoding ("aaaaa")
# Out:
# abc
# a2b1c5a3
# a2b1c5a2A7B1c1D1g3b2e1
# aabcccccaaAAAerAvBcDgggbbe
# a5
